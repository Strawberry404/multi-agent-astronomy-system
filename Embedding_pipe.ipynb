# %% [markdown]
# # Document/Text processing and embedding creation

# %% [markdown]
# * PDF document of choice (note: this could be almost any kind of document, I've just chosen to focus on PDFs for now) , in our case it an astronomy book
# * Embedding model of choice : from the sentence_transformer library
#
# Steps:
#
# Import PDF document.
# Process text for embedding (e.g. split into chunks of sentences).
# Embed text chunks with embedding model.
# Save embeddings to file for later (embeddings will store on file for many years or until you lose your hard drive).

# %%
# !pip install requests tqdm fitz
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached numpy-2.3.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached scipy-1.16.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.3 MB 4.2 MB/s eta 0:00:01
#    --------- ------------------------------ 0.8/3.3 MB 3.7 MB/s eta 0:00:01
# ...

# %%
# Import PDF Document
import os 
import requests

pdf_path = "Astronomy.pdf"

filename= pdf_path

# %%
import fitz 
from tqdm.auto import tqdm 

def text_formatter(text: str) -> str: 
    """Performs minor formatting on text."""
    cleaned_text = text.replace("\n", " ").strip()

    # Potentially more text formatting functions can go here
    return cleaned_text

def open_and_read_pdf(pdf_path: str) -> list[dict]:
    doc = fitz.open(pdf_path)
    pages_and_texts = [] 
    for page_number, page in tqdm(enumerate(doc)):
        text = page.get_text()
        text = text_formatter(text=text)
        pages_and_texts.append({"page_number": page_number - 41,
                                "page_char_count": len(text),
                                "page_word_count": len(text.split(" ")),
                                "page_setence_count_raw": len(text.split(". ")),
                                "page_token_count": len(text) / 4, # 1 token = ~4 characters
                                "text": text})
    return pages_and_texts

pages_and_texts = open_and_read_pdf(pdf_path=pdf_path)
pages_and_texts[:2]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import fitz
#       2 from tqdm.auto import tqdm
#       4 def text_formatter(text: str) -> str:
#
# File c:\Users\fatim\Metime\AstronomyRag\.venv\Lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# ModuleNotFoundError: No module named 'frontend'

# %%
import random

random.sample(pages_and_texts , k=3)
